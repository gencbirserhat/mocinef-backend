# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

file_path = '/content/drive/MyDrive/film_oneri/movies_dataset.csv'
df = pd.read_csv(file_path)

# Eksik değerleri temizle
df = df.dropna(subset=["overview"])

# Kullanılacak metin sütunlarını birleştir
def combine_text(row):
    return ' '.join([
        str(row["overview"]),
    ])

df["text"] = df.apply(combine_text, axis=1)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# TF-IDF vektörleştirici (isteğe göre sınırla)
tfidf = TfidfVectorizer(stop_words='english', max_features=10000)
tfidf_matrix = tfidf.fit_transform(df["text"])

# NMF ile konuları çıkar (örneğin 50 konulu bir model)
nmf = NMF(n_components=69, random_state=42)
nmf_features = nmf.fit_transform(tfidf_matrix)

# %%
def average_similarity_score(features, k=2):
    from sklearn.neighbors import NearestNeighbors

    nn = NearestNeighbors(n_neighbors=k, metric="cosine")
    nn.fit(features)
    distances, _ = nn.kneighbors(features)

    similarities = 1 - distances[:, 1:]  # ilk komşu kendisi → at
    avg_sim = np.mean(similarities)
    return round(avg_sim, 4)

avg_score = average_similarity_score(nmf_features, k=6)
print("🔍 Ortalama Benzerlik Skoru (Top-6):", avg_score)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-5de12979daed> in <cell line: 0>()
#      10     return round(avg_sim, 4)
#      11
# ---> 12 avg_score = average_similarity_score(nmf_features, k=6)
#      13 print("🔍 Ortalama Benzerlik Skoru (Top-6):", avg_score)
#
# <ipython-input-7-5de12979daed> in average_similarity_score(features, k)
#       4     nn = NearestNeighbors(n_neighbors=k, metric="cosine")
#       5     nn.fit(features)
# ----> 6     distances, _ = nn.kneighbors(features)
#       7
#       8     similarities = 1 - distances[:, 1:]  # ilk komşu kendisi → at
#
# /usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     904                 kwds = self.effective_metric_params_
#     905
# --> 906             chunked_results = list(
#     907                 pairwise_distances_chunked(
#     908                     X,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    2259         if reduce_func is not None:
#    2260             chunk_size = D_chunk.shape[0]
# -> 2261             D_chunk = reduce_func(D_chunk, sl.start)
#    2262             _check_chunk_size(D_chunk, chunk_size)
#    2263         yield D_chunk
#
# /usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py in _kneighbors_reduce_func(self, dist, start, n_neighbors, return_distance)
#     748         """
#     749         sample_range = np.arange(dist.shape[0])[:, None]
# --> 750         neigh_ind = np.argpartition(dist, n_neighbors - 1, axis=1)
#     751         neigh_ind = neigh_ind[:, :n_neighbors]
#     752         # argpartition doesn't guarantee sorted order, so we sort again
#
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py in argpartition(a, kth, axis, kind, order)
#     906
#     907     """
# --> 908     return _wrapfunc(a, 'argpartition', kth, axis=axis, kind=kind, order=order)
#     909
#     910
#
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55
#      56     try:
# ---> 57         return bound(*args, **kwds)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#
# KeyboardInterrupt:

# %%
print("🔧 NMF Reconstruction Error (Frobenius norm):", round(nmf.reconstruction_err_, 4))
# Out:
# 🔧 NMF Reconstruction Error (Frobenius norm): 629.3382

# %%
for k in [10, 20, 50, 100]:
    nmf = NMF(n_components=k).fit(tfidf_matrix)
    print(f"k={k}, Reconstruction Error: {nmf.reconstruction_err_:.2f}")
# Out:
# k=10, Reconstruction Error: 650.29
# k=20, Reconstruction Error: 645.28
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-3697f316ef47> in <cell line: 0>()
#       1 for k in [10, 20, 50, 100]:
# ----> 2     nmf = NMF(n_components=k).fit(tfidf_matrix)
#       3     print(f"k={k}, Reconstruction Error: {nmf.reconstruction_err_:.2f}")
#
# /usr/local/lib/python3.11/dist-packages/sklearn/decomposition/_nmf.py in fit(self, X, y, **params)
#    1294         # param validation is done in fit_transform
#    1295
# -> 1296         self.fit_transform(X, **params)
#    1297         return self
#    1298
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/decomposition/_nmf.py in fit_transform(self, X, y, W, H)
#    1638
#    1639         with config_context(assume_finite=True):
# -> 1640             W, H, n_iter = self._fit_transform(X, W=W, H=H)
#    1641
#    1642         self.reconstruction_err_ = _beta_divergence(
#
# /usr/local/lib/python3.11/dist-packages/sklearn/decomposition/_nmf.py in _fit_transform(self, X, y, W, H, update_H)
#    1706
#    1707         if self.solver == "cd":
# -> 1708             W, H, n_iter = _fit_coordinate_descent(
#    1709                 X,
#    1710                 W,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/decomposition/_nmf.py in _fit_coordinate_descent(X, W, H, tol, max_iter, l1_reg_W, l1_reg_H, l2_reg_W, l2_reg_H, update_H, verbose, shuffle, random_state)
#     499
#     500         # Update W
# --> 501         violation += _update_coordinate_descent(
#     502             X, W, Ht, l1_reg_W, l2_reg_W, shuffle, rng
#     503         )
#
# /usr/local/lib/python3.11/dist-packages/sklearn/decomposition/_nmf.py in _update_coordinate_descent(X, W, Ht, l1_reg, l2_reg, shuffle, random_state)
#     402     # The following seems to be required on 64-bit Windows w/ Python 3.5.
#     403     permutation = np.asarray(permutation, dtype=np.intp)
# --> 404     return _update_cdnmf_fast(W, HHt, XHt, permutation)
#     405
#     406
#
# KeyboardInterrupt:

# %%
from sklearn.metrics.pairwise import cosine_similarity

def recommend_from_two_nmf(title1, title2, top_n=5):
    idx1 = df[df["title"] == title1].index[0]
    idx2 = df[df["title"] == title2].index[0]

    vec1 = nmf_features[idx1]
    vec2 = nmf_features[idx2]
    combined_vec = (vec1 + vec2) / 2

    similarities = cosine_similarity([combined_vec], nmf_features)[0]

    # Kendi girdilerini çıkar
    similar_indices = similarities.argsort()[::-1]
    recs = []
    for i in similar_indices:
        if i not in [idx1, idx2]:
            recs.append((df.iloc[i]["title"], round(similarities[i], 3)))
        if len(recs) == top_n:
            break
    return recs

recommend_from_two_nmf("Inception", "The Matrix")
# Out:
# [('Thawed Carp', np.float64(0.822)),
#  ('Nitro', np.float64(0.814)),
#  ('Rage of Angels: The Story Continues', np.float64(0.808)),
#  ('Good to Go', np.float64(0.807)),
#  ('Letter from Eusapia', np.float64(0.788))]
