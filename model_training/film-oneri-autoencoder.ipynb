# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from IPython import get_ipython
from IPython.display import display

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/film_oneri/movies_dataset.csv'
df = pd.read_csv(file_path)

features = ['vote_average', 'vote_count', 'popularity', 'runtime', 'budget', 'revenue']
df_features = df[features].fillna(0)

scaler = StandardScaler()
X = scaler.fit_transform(df_features)

# %%
from tensorflow.keras import layers, models

input_dim = X.shape[1]
encoding_dim = 16  # Latent boyut

autoencoder = models.Sequential([
    layers.Input(shape=(input_dim,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(encoding_dim, activation='relu', name="encoded"),
    layers.Dense(32, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(input_dim, activation='linear')
])

autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoded (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,102 (23.84 KB)
#  Trainable params: 6,102 (23.84 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
autoencoder.fit(X, X, epochs=50, batch_size=32, shuffle=True, validation_split=0.1)
# Out:
# Epoch 1/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 58s 3ms/step - loss: 0.2281 - val_loss: 1.0589
# Epoch 2/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 53s 3ms/step - loss: 0.1032 - val_loss: 1.6800
# Epoch 3/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 54s 3ms/step - loss: 0.2088 - val_loss: 1.0959
# Epoch 4/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 81s 3ms/step - loss: 0.1683 - val_loss: 0.8388
# Epoch 5/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 54s 3ms/step - loss: 0.2771 - val_loss: 1.7609
# Epoch 6/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 54s 3ms/step - loss: 0.2347 - val_loss: 0.6239
# Epoch 7/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 83s 3ms/step - loss: 0.0357 - val_loss: 0.7635
# Epoch 8/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 81s 3ms/step - loss: 0.2067 - val_loss: 1.5786
# Epoch 9/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 81s 3ms/step - loss: 0.0701 - val_loss: 0.9587
# Epoch 10/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 54s 3ms/step - loss: 0.0497 - val_loss: 0.7379
# Epoch 11/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 54s 3ms/step - loss: 0.1674 - val_loss: 1.5096
# Epoch 12/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 83s 3ms/step - loss: 0.0708 - val_loss: 0.6674
# Epoch 13/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 82s 3ms/step - loss: 0.1312 - val_loss: 0.4609
# Epoch 14/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 53s 3ms/step - loss: 0.1064 - val_loss: 0.4605
# Epoch 15/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 82s 3ms/step - loss: 0.1458 - val_loss: 2.8365
# Epoch 16/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 82s 3ms/step - loss: 0.0335 - val_loss: 4.0551
# Epoch 17/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 53s 3ms/step - loss: 0.1271 - val_loss: 0.5763
# Epoch 18/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 53s 3ms/step - loss: 0.0143 - val_loss: 1.0659
# Epoch 19/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 83s 3ms/step - loss: 0.2361 - val_loss: 1.2350
# Epoch 20/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 81s 3ms/step - loss: 0.1345 - val_loss: 0.3457
# Epoch 21/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 53s 3ms/step - loss: 0.1453 - val_loss: 0.6931
# Epoch 22/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 53s 3ms/step - loss: 0.1589 - val_loss: 0.1879
# Epoch 23/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 55s 3ms/step - loss: 0.0370 - val_loss: 0.4722
# Epoch 24/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 53s 3ms/step - loss: 0.1270 - val_loss: 1.1529
# Epoch 25/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 83s 3ms/step - loss: 0.2316 - val_loss: 0.4319
# Epoch 26/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 55s 3ms/step - loss: 0.0481 - val_loss: 0.0537
# Epoch 27/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 54s 3ms/step - loss: 0.0377 - val_loss: 0.1711
# Epoch 28/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 81s 3ms/step - loss: 0.0878 - val_loss: 0.4539
# Epoch 29/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 54s 3ms/step - loss: 0.0667 - val_loss: 0.2860
# Epoch 30/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 82s 3ms/step - loss: 0.0513 - val_loss: 0.0989
# Epoch 31/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 82s 3ms/step - loss: 0.0177 - val_loss: 0.6647
# Epoch 32/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 83s 3ms/step - loss: 0.1124 - val_loss: 0.1143
# Epoch 33/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 80s 3ms/step - loss: 0.0144 - val_loss: 1.3193
# Epoch 34/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 54s 3ms/step - loss: 0.1003 - val_loss: 0.3635
# Epoch 35/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 54s 3ms/step - loss: 0.1268 - val_loss: 0.3402
# Epoch 36/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 52s 3ms/step - loss: 0.0302 - val_loss: 0.7060
# Epoch 37/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 83s 3ms/step - loss: 0.1635 - val_loss: 0.3347
# Epoch 38/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 54s 3ms/step - loss: 0.1151 - val_loss: 0.3020
# Epoch 39/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 81s 3ms/step - loss: 0.0241 - val_loss: 0.2299
# Epoch 40/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 81s 3ms/step - loss: 0.0401 - val_loss: 0.5095
# Epoch 41/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 86s 3ms/step - loss: 0.0178 - val_loss: 0.0625
# Epoch 42/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 57s 3ms/step - loss: 0.0169 - val_loss: 0.4566
# Epoch 43/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 81s 3ms/step - loss: 0.0389 - val_loss: 0.4224
# Epoch 44/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 57s 3ms/step - loss: 0.1568 - val_loss: 0.4340
# Epoch 45/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 55s 3ms/step - loss: 0.0203 - val_loss: 0.0363
# Epoch 46/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 81s 3ms/step - loss: 0.0203 - val_loss: 0.8821
# Epoch 47/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 82s 3ms/step - loss: 0.0214 - val_loss: 0.2032
# Epoch 48/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 83s 3ms/step - loss: 0.1512 - val_loss: 0.0317
# Epoch 49/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 82s 3ms/step - loss: 0.0335 - val_loss: 0.7649
# Epoch 50/50
# 20329/20329 ━━━━━━━━━━━━━━━━━━━━ 54s 3ms/step - loss: 0.0185 - val_loss: 0.2795

# %%
from tensorflow.keras import layers, models

encoder = models.Model(inputs=autoencoder.layers[0].input, outputs=autoencoder.get_layer("encoded").output)
X_encoded = encoder.predict(X)
# Out:
# 22588/22588 ━━━━━━━━━━━━━━━━━━━━ 33s 1ms/step

# %%
def recommend_from_two_autoencoder(title1, title2, top_n=5):
    idx1 = df[df["title"] == title1].index[0]
    idx2 = df[df["title"] == title2].index[0]

    vec1 = X_encoded[idx1]
    vec2 = X_encoded[idx2]
    combined_vec = (vec1 + vec2) / 2

    sims = cosine_similarity([combined_vec], X_encoded)[0]

    similar_indices = sims.argsort()[::-1]
    recs = []
    for idx in similar_indices:
        if idx not in [idx1, idx2]:
            recs.append((df.iloc[idx]["title"], round(sims[idx], 3)))
        if len(recs) >= top_n:
            break
    return recs

recommend_from_two_autoencoder("Interstellar", "Inception")
# Out:
# [('Now You See Me', np.float32(0.999)),
#  ('Bridge of Spies', np.float32(0.999)),
#  ('Sin City', np.float32(0.998)),
#  ('The Fast and the Furious', np.float32(0.998)),
#  ('Iron Man', np.float32(0.998))]

# %%
autoencoder.save("autoencoder_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model
from sklearn.metrics import mean_squared_error, mean_absolute_error
# Define the path to save and load the model on Google Drive
model_path = '/content/drive/MyDrive/film_oneri/autoencoder_model.h5'

# Load the model from the specified path on Google Drive
autoencoder = load_model(model_path, compile=False)

# %%
X_pred = autoencoder.predict(X)  # X zaten dense numpy array

from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(X, X_pred)
mae = mean_absolute_error(X, X_pred)

print("🔹 MSE:", round(mse, 6))
print("🔹 MAE:", round(mae, 6))
# Out:
# 22588/22588 ━━━━━━━━━━━━━━━━━━━━ 31s 1ms/step
# 🔹 MSE: 0.05979
# 🔹 MAE: 0.009582
